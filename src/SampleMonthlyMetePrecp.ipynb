# %%
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = 'plotly_white'
plot_template = dict(
    layout=go.Layout({
        'font_size': 8,
        'xaxis_title_font_size': 8,
        'yaxis_title_font_size': 8,
        }   
))
import pandas as pd

# %%
# Read and process data
maduo = pd.read_csv('D:/DataSpace/HydroMeteAnthropicDatabase/7.FilledRawMeteObsInfo/ChinaLandDailyMeteV3(InsertSolarRadiation)/玛多.csv', index_col=['DATE'], parse_dates=['DATE'])
maduo = maduo['P2020(mm)']
maduo = maduo.resample('MS').sum()

# Visualize monthly streamflow using bar chart
fig = go.Figure()
fig.add_trace(go.Bar(x=maduo.index, y=maduo.values))
# fig.update_layout(
#     title='Monthly Streamflow',
#     xaxis_title='Date',
#     yaxis_title='Streamflow (mm)',
#     **plot_template
# )
fig.show()
