# %%
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = 'plotly_white'
plot_template = dict(
    layout=go.Layout({
        'font_size': 8,
        'xaxis_title_font_size': 8,
        'yaxis_title_font_size': 8,
        }   
))

# %%
hydro_station = 'Tangnaihai'
hydro_station_abbr = 'TNH'

pred_years = np.arange(2015,2020)
pred_df_swatp_simyr = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'),columns=['obs','pred'])
pred_df_swatp_simyr.index.name='date'

pred_df_swatp_ssp126 = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'),columns=['obs','pred'])
pred_df_swatp_ssp126.index.name = 'date'

pred_df_swatp_ssp245 = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'),columns=['obs','pred'])
pred_df_swatp_ssp245.index.name = 'date'

pred_df_swatp_ssp585 = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'),columns=['obs','pred'])
pred_df_swatp_ssp585.index.name = 'date'


pred_df_swatp_arima_simyr = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'),columns=['obs','pred'])
pred_df_swatp_arima_simyr.index.name = 'date'

pred_df_swatp_arima_ssp126 = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'),columns=['obs','pred'])
pred_df_swatp_arima_ssp126.index.name = 'date'

pred_df_swatp_arima_ssp245 = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'),columns=['obs','pred'])
pred_df_swatp_arima_ssp245.index.name = 'date'

pred_df_swatp_arima_ssp585 = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'),columns=['obs','pred'])
pred_df_swatp_arima_ssp585.index.name = 'date'

obs_df = pd.read_csv(f'../data/{hydro_station.lower()}_natural_monthly_flow.csv',index_col=['date'],parse_dates=['date'])
# arima_pred = pd.read_csv(f'../result/ARIMAPredData/seasonal_decompose_multiplicative_arima_pred_{hydro_station.lower()}_2015_2019.csv',index_col=['date'],parse_dates=['date'])
arima_pred = pd.read_csv(f'../result/ARIMAPredData/seasonal_decompose_additive_arima_pred_{hydro_station.lower()}_2015_2019.csv',index_col=['date'],parse_dates=['date'])
for pred_year in pred_years:
    date_range = pd.date_range(start=f'{pred_year}-01-01',end=f'{pred_year}-12-31',freq='MS')

    set_index = pd.DatetimeIndex(date_range)

    pred_data_swatp_simy = pd.read_csv(f'../result/SWATPlusPredUsingSimYearData/Channel_3_Monthly_River-Flow_{hydro_station_abbr}_pred{pred_year}.csv',index_col=['Date'],parse_dates=['Date'])
    pred_data_swatp_clip_ssp126 = pd.read_csv(f'../result/SWATPlusPredUsingClimatePatternData/Channel_3_Monthly_River-Flow_{hydro_station_abbr}_ssp126_pred{pred_year}.csv',index_col=['Date'],parse_dates=['Date'])
    pred_data_swatp_clip_ssp245 = pd.read_csv(f'../result/SWATPlusPredUsingClimatePatternData/Channel_3_Monthly_River-Flow_{hydro_station_abbr}_ssp245_pred{pred_year}.csv',index_col=['Date'],parse_dates=['Date'])
    pred_data_swatp_clip_ssp585 = pd.read_csv(f'../result/SWATPlusPredUsingClimatePatternData/Channel_3_Monthly_River-Flow_{hydro_station_abbr}_ssp585_pred{pred_year}.csv',index_col=['Date'],parse_dates=['Date'])
    
    
    
    pred_df_swatp_simyr.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','pred'] = pred_data_swatp_simy.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','Value'].values
    pred_df_swatp_simyr.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','obs'] = obs_df.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','flow(m^3/s)'].values

    pred_df_swatp_ssp126.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','pred'] = pred_data_swatp_clip_ssp126.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','Value'].values
    pred_df_swatp_ssp126.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','obs'] = obs_df.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','flow(m^3/s)'].values

    pred_df_swatp_ssp245.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','pred'] = pred_data_swatp_clip_ssp245.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','Value'].values
    pred_df_swatp_ssp245.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','obs'] = obs_df.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','flow(m^3/s)'].values

    pred_df_swatp_ssp585.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','pred'] = pred_data_swatp_clip_ssp585.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','Value'].values
    pred_df_swatp_ssp585.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','obs'] = obs_df.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','flow(m^3/s)'].values
    
    
    pred_df_swatp_arima_simyr.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','pred'] = pred_data_swatp_simy.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','Value'].values
    pred_df_swatp_arima_simyr.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','obs'] = obs_df.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','flow(m^3/s)'].values

    pred_df_swatp_arima_ssp126.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','pred'] = pred_data_swatp_clip_ssp126.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','Value'].values
    pred_df_swatp_arima_ssp126.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','obs'] = obs_df.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','flow(m^3/s)'].values

    pred_df_swatp_arima_ssp245.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','pred'] = pred_data_swatp_clip_ssp245.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','Value'].values
    pred_df_swatp_arima_ssp245.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','obs'] = obs_df.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','flow(m^3/s)'].values

    
    pred_df_swatp_arima_ssp585.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','pred'] = pred_data_swatp_clip_ssp585.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','Value'].values
    pred_df_swatp_arima_ssp585.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','obs'] = obs_df.loc[f'{pred_year}-01-01':f'{pred_year}-12-31','flow(m^3/s)'].values

   

    # Save the corrected predictions for each SSP scenario
    pred_df_swatp_arima_ssp126.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_ARIMA_corrected_pred_obs_ssp126_2015_2019.csv')
    pred_df_swatp_arima_ssp245.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_ARIMA_corrected_pred_obs_ssp245_2015_2019.csv')
    pred_df_swatp_arima_ssp585.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_ARIMA_corrected_pred_obs_ssp585_2015_2019.csv')

    # Save the uncorrected predictions for each SSP scenario
    pred_df_swatp_ssp126.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_pred_obs_ssp126_2015_2019.csv')
    pred_df_swatp_ssp245.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_pred_obs_ssp245_2015_2019.csv')
    pred_df_swatp_ssp585.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_pred_obs_ssp585_2015_2019.csv')


    # arima_pred_5_10 = arima_pred.loc[f'{pred_year}-05-01':f'{pred_year}-11-30']
    arima_pred_6_9 = arima_pred.loc[f'{pred_year}-06-01':f'{pred_year}-10-31']
    
    arima_pred_6_9_sum = arima_pred_6_9['flow(m^3/s)'].sum()
    # print(arima_pred_5_10_sum)

    # pred_data_5_10 = pred_df_swatplus_arima.loc[f'{pred_year}-05-01':f'{pred_year}-11-30']
    swatp_simyr_pred_data_6_9 = pred_df_swatp_arima_simyr.loc[f'{pred_year}-06-01':f'{pred_year}-10-31']
    swatp_simyr_pred_data_6_9 = swatp_simyr_pred_data_6_9['pred'].sum()
    # print(pred_data_5_10_sum)

    swatp_simyr_factor = arima_pred_6_9_sum/swatp_simyr_pred_data_6_9
    print(arima_pred_6_9_sum,swatp_simyr_pred_data_6_9,swatp_simyr_factor)

    swatp_ssp126_pred_data_6_9 = pred_df_swatp_ssp126.loc[f'{pred_year}-06-01':f'{pred_year}-10-31']
    swatp_ssp126_pred_data_6_9 = swatp_ssp126_pred_data_6_9['pred'].sum()

    swatp_ssp126_factor = arima_pred_6_9_sum/swatp_ssp126_pred_data_6_9
    print(arima_pred_6_9_sum,swatp_ssp126_pred_data_6_9,swatp_ssp126_factor)

    swatp_ssp245_pred_data_6_9 = pred_df_swatp_ssp245.loc[f'{pred_year}-06-01':f'{pred_year}-10-31']
    swatp_ssp245_pred_data_6_9 = swatp_ssp245_pred_data_6_9['pred'].sum()

    swatp_ssp245_factor = arima_pred_6_9_sum/swatp_ssp245_pred_data_6_9
    print(arima_pred_6_9_sum,swatp_ssp245_pred_data_6_9,swatp_ssp245_factor)

    swatp_ssp585_pred_data_6_9 = pred_df_swatp_ssp585.loc[f'{pred_year}-06-01':f'{pred_year}-10-31']
    swatp_ssp585_pred_data_6_9 = swatp_ssp585_pred_data_6_9['pred'].sum()

    swatp_ssp585_factor = arima_pred_6_9_sum/swatp_ssp585_pred_data_6_9
    print(arima_pred_6_9_sum,swatp_ssp585_pred_data_6_9,swatp_ssp585_factor)


    pred_df_swatp_arima_simyr.loc[f'{pred_year}-06-01':f'{pred_year}-10-31','pred'] = pred_df_swatp_arima_simyr.loc[f'{pred_year}-06-01':f'{pred_year}-10-31','pred']*swatp_simyr_factor
    pred_df_swatp_arima_ssp126.loc[f'{pred_year}-06-01':f'{pred_year}-10-31','pred'] = pred_df_swatp_arima_ssp126.loc[f'{pred_year}-06-01':f'{pred_year}-10-31','pred']*swatp_ssp126_factor
    pred_df_swatp_arima_ssp245.loc[f'{pred_year}-06-01':f'{pred_year}-10-31','pred'] = pred_df_swatp_arima_ssp245.loc[f'{pred_year}-06-01':f'{pred_year}-10-31','pred']*swatp_ssp245_factor
    pred_df_swatp_arima_ssp585.loc[f'{pred_year}-06-01':f'{pred_year}-10-31','pred'] = pred_df_swatp_arima_ssp585.loc[f'{pred_year}-06-01':f'{pred_year}-10-31','pred']*swatp_ssp585_factor


pred_df_swatp_arima_simyr.to_csv(f'../result/SWATPlusPredUsingSimYearData/{hydro_station}_SWATPlus_corrected_pred_obs_2015_2019.csv')

pred_df_swatp_simyr.to_csv(f'../result/SWATPlusPredUsingSimYearData/{hydro_station}_SWATPlus_pred_obs_2015_2019.csv')
pred_df_swatp_ssp126.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_pred_obs_ssp126_2015_2019.csv')
pred_df_swatp_ssp245.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_pred_obs_ssp245_2015_2019.csv')
pred_df_swatp_ssp585.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_pred_obs_ssp585_2015_2019.csv')

pred_df_swatp_arima_ssp126.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_corrected_pred_obs_ssp126_2015_2019.csv')
pred_df_swatp_arima_ssp245.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_corrected_pred_obs_ssp245_2015_2019.csv')
pred_df_swatp_arima_ssp585.to_csv(f'../result/SWATPlusPredUsingClimatePatternData/{hydro_station}_SWATPlus_corrected_pred_obs_ssp585_2015_2019.csv')

print('R2 for corrected SWATPlus-ARIMA:',r2_score(pred_df_swatp_arima_simyr['obs'],pred_df_swatp_arima_simyr['pred']))
print('R2 for ARIMA:',r2_score(obs_df.loc[f'2015-01-01':f'2019-12-31','flow(m^3/s)'],arima_pred.loc[f'2015-01-01':f'2019-12-31','flow(m^3/s)']))
print('R2 for SWATPlus SimYr:',r2_score(pred_df_swatp_simyr['obs'],pred_df_swatp_simyr['pred']))
print('R2 for SWATPlus SSP126:',r2_score(pred_df_swatp_ssp126['obs'],pred_df_swatp_ssp126['pred']))
print('R2 for SWATPlus SSP245:',r2_score(pred_df_swatp_ssp245['obs'],pred_df_swatp_ssp245['pred']))
print('R2 for SWATPlus SSP585:',r2_score(pred_df_swatp_ssp585['obs'],pred_df_swatp_ssp585['pred']))
print('R2 for SWATPlus+ARIMA SimYr:',r2_score(pred_df_swatp_arima_simyr['obs'],pred_df_swatp_arima_simyr['pred']))
print('R2 for SWATPlus+ARIMA SSP126:',r2_score(pred_df_swatp_arima_ssp126['obs'],pred_df_swatp_arima_ssp126['pred']))
print('R2 for SWATPlus+ARIMA SSP245:',r2_score(pred_df_swatp_arima_ssp245['obs'],pred_df_swatp_arima_ssp245['pred']))
print('R2 for SWATPlus+ARIMA SSP585:',r2_score(pred_df_swatp_arima_ssp585['obs'],pred_df_swatp_arima_ssp585['pred']))

# visualize
fig = px.line(pred_df_swatp_arima_simyr,x=pred_df_swatp_arima_simyr.index,y=['obs'],labels={'index':'Date','obs':'Observed'},title='SWATPlus')
fig.add_trace(go.Line(x=pred_df_swatp_simyr.index,y=pred_df_swatp_simyr['pred'],mode='lines',name='SWATPlus Pred',line=dict(color='purple')))
fig.add_trace(go.Line(x=pred_df_swatp_arima_simyr.index,y=pred_df_swatp_arima_simyr['pred'],mode='lines',name='SWATPlus-ARIMA Pred',line=dict(color='green')))
fig.add_trace(go.Line(x=pred_df_swatp_arima_ssp126.index,y=pred_df_swatp_arima_ssp126['pred'],mode='lines',name='SWATPlus-ARIMA SSP126',line=dict(color='blue')))
fig.add_trace(go.Line(x=pred_df_swatp_arima_ssp245.index,y=pred_df_swatp_arima_ssp245['pred'],mode='lines',name='SWATPlus-ARIMA SSP245',line=dict(color='orange')))
fig.add_trace(go.Line(x=pred_df_swatp_arima_ssp585.index,y=pred_df_swatp_arima_ssp585['pred'],mode='lines',name='SWATPlus-ARIMA SSP585',line=dict(color='red')))
fig.add_trace(go.Line(x=pred_df_swatp_ssp126.index,y=pred_df_swatp_ssp126['pred'],mode='lines',name='SWATPlus SSP126',line=dict(color='lightblue')))
fig.add_trace(go.Line(x=pred_df_swatp_ssp245.index,y=pred_df_swatp_ssp245['pred'],mode='lines',name='SWATPlus SSP245',line=dict(color='cyan')))
fig.add_trace(go.Line(x=pred_df_swatp_ssp585.index,y=pred_df_swatp_ssp585['pred'],mode='lines',name='SWATPlus SSP585',line=dict(color='pink')))

fig.show()
# Out:
# 5720.880471935375 6732.0 0.8498039916719213
# 5720.880471935375 5660.7 1.0106312773924382
# 5720.880471935375 4456.5 1.2837160264636767
# 5720.880471935375 4452.2 1.284955858212878
# 4313.293400878884 3450.7 1.2499763528788028
# 4313.293400878884 2084.1 2.0696192125516455
# 4313.293400878884 2087.4 2.066347322448445
# 4313.293400878884 2090.0 2.063776746832002
# 4341.266206596194 2995.7 1.4491658732837716
# 4341.266206596194 1859.7 2.334390604181424
# 4341.266206596194 1859.0000000000002 2.3352696108640094
# 4341.266206596194 1861.6000000000001 2.3320080611281657
# 6939.019140069921 5494.1 1.2629946925010322
# 6939.019140069921 4150.7 1.6717708193967094
# 6939.019140069921 4149.5 1.672254281255554
# 6939.019140069921 4302.5 1.6127877141359492
# 5929.980019640929 4951.799999999999 1.1975402923464054
# 5929.980019640929 3126.5 1.8966831983498893
# 5929.980019640929 3124.6000000000004 1.8978365293608552
# 5929.980019640929 3120.9 1.9000865197990735
# ...

# %%
SWATPlus_simu = pd.read_csv(f'../result/SWATPlusCalValSimData/Channel_3_Monthly_River-Flow_{hydro_station}_Sim1972_2019.csv',index_col=['Date'],parse_dates=['Date'])
SWATPlus_simu = SWATPlus_simu.loc[f'2015-01-01':f'2019-12-31',:]
obs_df = pd.read_csv(f'../data/{hydro_station.lower()}_natural_monthly_flow.csv',index_col=['date'],parse_dates=['date'])
obs_df = obs_df.loc[f'2015-01-01':f'2019-12-31',:]

df = pd.DataFrame(index=pd.date_range(start='2015-01-01',end='2019-12-31',freq='MS'))
df['obs'] = obs_df['flow(m^3/s)'].values
df['SWATPlus'] = SWATPlus_simu['Value'].values

print(r2_score(df['obs'],df['SWATPlus']))
# visualize
fig = go.Figure()
fig.add_trace(go.Line(x=df.index,y=df['obs'],mode='lines',name='Observed',line=dict(color='black')))
fig.add_trace(go.Line(x=df.index,y=df['SWATPlus'],mode='lines',name='SWATPlus Simulated',line=dict(color='red')))
fig.add_trace(go.Line(x=df.index,y=pred_df_swatp_simyr['pred'],mode='lines',name='SWATPlus Pred',line=dict(color='purple')))
fig.add_trace(go.Line(x=pred_df_swatp_arima_simyr.index,y=pred_df_swatp_arima_simyr['pred'],mode='lines',name='SWATPlus-ARIMA Pred',line=dict(color='green')))
fig.add_trace(go.Line(x=pred_df_swatp_arima_ssp126.index,y=pred_df_swatp_arima_ssp126['pred'],mode='lines',name='SWATPlus-ARIMA Pred',line=dict(color='blue')))
fig.add_trace(go.Line(x=pred_df_swatp_arima_ssp245.index,y=pred_df_swatp_arima_ssp245['pred'],mode='lines',name='SWATPlus-ARIMA Pred',line=dict(color='cyan')))
fig.add_trace(go.Line(x=pred_df_swatp_arima_ssp585.index,y=pred_df_swatp_arima_ssp585['pred'],mode='lines',name='SWATPlus-ARIMA Pred',line=dict(color='pink')))
fig.show()
# Out:
# 0.8230361320359836
# c:\Users\ZJY\miniconda3\envs\pyTorch\Lib\site-packages\plotly\graph_objs\_deprecations.py:378: DeprecationWarning:
#
# plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
