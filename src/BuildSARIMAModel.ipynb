# %%
import pandas as pd
import matplotlib.pyplot as plt
from ADF_test import is_stationary
import pmdarima as pm
from pmdarima.model_selection import train_test_split
import numpy as np
from sklearn.metrics import r2_score
from statsmodels.tsa.seasonal import seasonal_decompose
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
pio.templates.default = 'plotly_white'
plot_template = dict(
    layout=go.Layout({
        'font_size': 8,
        'xaxis_title_font_size': 8,
        'yaxis_title_font_size': 8,
        }   
))
hydro_stations = ['Tangnaihai','Guide','Xunhua']

# %%
for hydro_station in hydro_stations:
    df = pd.read_csv(f'../data/{hydro_station.lower()}_natural_monthly_flow.csv', parse_dates=['date'], index_col='date')
    # compute the average flow before 2014-12-31
    df_avg_before_2014 = df.loc[:'2014-12-31','flow(m^3/s)'].mean()
    df.info()
    fig = go.Figure()
    fig.add_trace(go.Scatter(x=df.index, y=df['flow(m^3/s)'], mode='lines', name=f'{hydro_station} River'))
    fig.add_shape(
        type="line",
        x0=df.index[0],
        y0=df_avg_before_2014,
        x1=df.index[-1],
        y1=df_avg_before_2014,
        line=dict(color="Red", width=2)
    )
    fig.update_layout(title=f'Yellow River Monthly Flow at {hydro_station}',
                       xaxis_title='Date',
                       yaxis_title='Flow (m^3/s)')
    fig.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 840 entries, 1950-01-01 to 2019-12-01
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   flow(m^3/s)  840 non-null    float64
# dtypes: float64(1)
# memory usage: 45.4 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 756 entries, 1957-01-01 to 2019-12-01
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   flow(m^3/s)  756 non-null    float64
# dtypes: float64(1)
# memory usage: 28.0 KB
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 756 entries, 1957-01-01 to 2019-12-01
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   flow(m^3/s)  756 non-null    float64
# dtypes: float64(1)
# memory usage: 28.0 KB

# %%
val_years = np.arange(2009,2015)
test_obs = df.loc["2009-01-01":"2014-12-31",:]
for hydro_station in hydro_stations:
    df = pd.read_csv(f'../data/{hydro_station.lower()}_natural_monthly_flow.csv', parse_dates=['date'], index_col='date')
    modes = [
        'multiplicative',
        # 'additive'
    ]
    for mode in modes:
        test_pred = pd.DataFrame()
        train_r2_list = []
        for year in val_years:
            train = df.loc[:"{}-12-31".format(year-1),:]
            test = df.loc["{}-01-01".format(year):"{}-12-31".format(year),:]
            decomposition = seasonal_decompose(train['flow(m^3/s)'], model=mode, period=12,extrapolate_trend=1)
            trend = decomposition.trend
            seasonal = decomposition.seasonal
            residual = decomposition.resid
            # fit the ARIMA model to the trend component
            model = pm.auto_arima(trend, 
                                  seasonal=False, 
                                  information_criterion='bic',
                                  trace=True,
                                  error_action='ignore',  
                                  suppress_warnings=True, 
                                  stepwise=True)
            model.summary()
            train_trend_pred = model.predict_in_sample()
            test_trend_pred = model.predict(n_periods=len(test))
            # fit the ARIMA model to the seasonal component
            model = pm.auto_arima(seasonal, 
                                  m = 12,
                                  seasonal_test = 'ch',
                                  seasonal=True, 
                                  information_criterion='bic',
                                  trace=True,
                                  error_action='ignore',  
                                  suppress_warnings=True, 
                                  stepwise=True)
            model.summary()
            train_seasonal_pred = model.predict_in_sample()
            test_seasonal_pred = model.predict(n_periods=len(test))
            # fit the ARIMA model to the residual component
            model = pm.auto_arima(residual, 
                                  seasonal=False, 
                                  information_criterion='bic',
                                  trace=True,
                                  error_action='ignore',  
                                  suppress_warnings=True, 
                                  stepwise=True)
            model.summary()
            train_residual_pred = model.predict_in_sample()
            test_residual_pred = model.predict(n_periods=len(test))
            # combine the trend, seasonal, and residual components
            if mode == 'multiplicative':
                train_pred_year = train_trend_pred * train_seasonal_pred * train_residual_pred
                test_pred_year = test_trend_pred * test_seasonal_pred * test_residual_pred
            else:
                train_pred_year = train_trend_pred + train_seasonal_pred + train_residual_pred
                test_pred_year = test_trend_pred + test_seasonal_pred + test_residual_pred

            train_pred_year.index = train.index
            train_pred_year.name = "SimFlow(m^3/s)"
            train_result = pd.concat([train,train_pred_year],axis=1)
            train_result.to_csv(f'../result/ARIMAPredData/seasonal_decompose_{mode}_arima_train_sim_{hydro_station.lower()}_before_{year}.csv')
            train_r2 = r2_score(train['flow(m^3/s)'], train_pred_year)
            train_r2_list.append(train_r2)
            test_pred_year.index = test.index
            test_pred_year.name = "flow(m^3/s)"
            test_pred = pd.concat([test_pred,test_pred_year])

        print(sum(train_r2_list)/len(train_r2_list))
        print(test_pred)
        print(r2_score(test_obs,test_pred)) # 0.6934 multiplicative;0.5988 additive
        test_pred.index.name = 'date'
        test_pred.to_csv(f'../result/ARIMAPredData/seasonal_decompose_{mode}_arima_pred_{hydro_station.lower()}_{val_years[0]}_{val_years[-1]}.csv')

        # visualize the results using plotly
        fig = go.Figure()
        fig.add_trace(go.Scatter(x=test_obs.index, y=test_obs['flow(m^3/s)'], mode='lines', name='Observed'))
        fig.add_trace(go.Scatter(x=test_pred.index, y=test_pred['flow(m^3/s)'], mode='lines', name='Predicted'))
        fig.show()
# Out:
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.38 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=6773.615, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=6217.637, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=6767.055, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6084.398, Time=0.08 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6008.107, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=5974.998, Time=0.14 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=5949.048, Time=0.15 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.57 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.49 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=5942.487, Time=0.11 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=5968.437, Time=0.09 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.44 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.32 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.064 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=5.33 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1368.201, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.44 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.62 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2252.461, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.04 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.51 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.88 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=583.283, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.62 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.51 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=170.458, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.57 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.72 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.68 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=36.231, Time=0.17 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.25 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.81 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.76 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-290.705, Time=0.20 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.60 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.88 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.67 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.35 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-729.266, Time=0.89 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-5792.337, Time=2.99 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-6735.685, Time=6.96 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=2.35 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : BIC=-6672.651, Time=8.05 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=4.51 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-6405.955, Time=7.57 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-8107.866, Time=9.75 sec
#  ARIMA(4,0,2)(1,0,0)[12] intercept   : BIC=-6911.376, Time=3.19 sec
#  ARIMA(4,0,2)(2,0,1)[12] intercept   : BIC=-10090.986, Time=5.37 sec
#  ARIMA(4,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=2.51 sec
#  ARIMA(4,0,2)(2,0,2)[12] intercept   : BIC=inf, Time=14.16 sec
#  ARIMA(4,0,2)(1,0,2)[12] intercept   : BIC=inf, Time=4.61 sec
#  ARIMA(3,0,2)(2,0,1)[12] intercept   : BIC=-8943.317, Time=10.72 sec
#  ARIMA(5,0,2)(2,0,1)[12] intercept   : BIC=-9064.522, Time=11.96 sec
#  ARIMA(4,0,3)(2,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,1)(2,0,1)[12] intercept   : BIC=-9405.809, Time=5.92 sec
#  ARIMA(3,0,3)(2,0,1)[12] intercept   : BIC=-7962.248, Time=9.80 sec
#  ARIMA(5,0,1)(2,0,1)[12] intercept   : BIC=-9627.561, Time=8.31 sec
#  ARIMA(5,0,3)(2,0,1)[12] intercept   : BIC=-9317.078, Time=7.07 sec
#  ARIMA(4,0,2)(2,0,1)[12]             : BIC=-8878.450, Time=2.97 sec
#
# Best model:  ARIMA(4,0,2)(2,0,1)[12] intercept
# Total fit time: 160.729 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.35 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2048.194, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=150.884, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1342.337, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=128.973, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=102.296, Time=0.06 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=88.112, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.36 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.26 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : BIC=inf, Time=0.43 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-156.145, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-140.927, Time=0.11 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-171.559, Time=0.20 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-169.098, Time=0.53 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-171.401, Time=0.72 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 3.450 seconds
# Performing stepwise search to minimize bic
# C:\Users\ZJY\AppData\Local\Temp\ipykernel_39020\2992677552.py:69: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.43 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=6887.611, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=6314.784, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=6881.084, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6177.100, Time=0.08 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6097.139, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6061.071, Time=0.14 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6030.610, Time=0.18 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.59 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.50 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6024.043, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6054.508, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.48 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.39 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.258 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=3.59 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1391.600, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.96 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.62 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2290.657, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.79 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.41 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=592.085, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.16 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=168.739, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.78 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.67 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.18 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=30.770, Time=0.12 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.06 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.74 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.64 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-299.037, Time=0.19 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.85 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.86 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.76 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.30 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-730.431, Time=0.77 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-5511.772, Time=2.70 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-6921.051, Time=8.14 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=4.81 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=1.63 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=4.88 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-7101.280, Time=7.11 sec
#  ARIMA(5,0,1)(1,0,0)[12] intercept   : BIC=-6326.732, Time=2.44 sec
#  ARIMA(5,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=6.20 sec
#  ARIMA(5,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=2.21 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.12 sec
#  ARIMA(5,0,2)(2,0,0)[12] intercept   : BIC=-8410.515, Time=11.03 sec
#  ARIMA(5,0,2)(1,0,0)[12] intercept   : BIC=-5579.981, Time=2.81 sec
#  ARIMA(5,0,2)(2,0,1)[12] intercept   : BIC=-7867.521, Time=7.83 sec
#  ARIMA(5,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=2.96 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-6591.216, Time=10.73 sec
#  ARIMA(5,0,3)(2,0,0)[12] intercept   : BIC=-7092.624, Time=8.07 sec
#  ARIMA(4,0,3)(2,0,0)[12] intercept   : BIC=inf, Time=5.81 sec
#  ARIMA(5,0,2)(2,0,0)[12]             : BIC=-8845.965, Time=8.61 sec
#  ARIMA(5,0,2)(1,0,0)[12]             : BIC=-7171.764, Time=3.43 sec
#  ARIMA(5,0,2)(2,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(5,0,2)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,2)(2,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(5,0,1)(2,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(5,0,3)(2,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,1)(2,0,0)[12]             : BIC=-8309.700, Time=2.21 sec
#  ARIMA(4,0,3)(2,0,0)[12]             : BIC=-7213.212, Time=2.38 sec
#
# Best model:  ARIMA(5,0,2)(2,0,0)[12]
# Total fit time: 176.286 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.27 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2083.751, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=144.609, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1364.470, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=122.320, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=95.150, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=80.567, Time=0.06 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.06 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.33 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.31 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : BIC=inf, Time=0.41 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-167.277, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-151.927, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-183.251, Time=0.20 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-180.673, Time=0.66 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-182.742, Time=0.54 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 3.287 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=7013.952, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=6427.109, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=7007.521, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6293.819, Time=0.08 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6211.347, Time=0.11 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6178.955, Time=0.13 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6154.003, Time=0.15 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.50 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.51 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6147.464, Time=0.09 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6172.419, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.44 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.39 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.025 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=1.78 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1417.613, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.24 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.46 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2329.597, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.64 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.08 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=612.492, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.44 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.48 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=209.986, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.69 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.59 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.46 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=63.556, Time=0.14 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.47 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.79 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.51 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-275.253, Time=0.20 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.38 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.91 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.14 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.35 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-718.313, Time=0.76 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-7386.213, Time=3.92 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-6174.946, Time=10.03 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=2.95 sec
#  ARIMA(4,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=1.32 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=6.11 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : BIC=-6927.847, Time=2.45 sec
#  ARIMA(5,0,1)(1,0,0)[12] intercept   : BIC=-7442.054, Time=4.17 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=-743.018, Time=0.84 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-8017.415, Time=6.36 sec
#  ARIMA(5,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=12.26 sec
#  ARIMA(5,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=5.50 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.79 sec
#  ARIMA(5,0,2)(2,0,0)[12] intercept   : BIC=-5317.398, Time=9.33 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=13.54 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-7184.446, Time=10.06 sec
#  ARIMA(5,0,1)(2,0,0)[12]             : BIC=inf, Time=nan sec
#
# Best model:  ARIMA(5,0,1)(2,0,0)[12] intercept
# Total fit time: 129.160 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2122.109, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=162.903, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1390.117, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=142.574, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=111.016, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.32 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : BIC=inf, Time=0.23 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.34 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-141.572, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=-134.597, Time=0.13 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-153.357, Time=0.14 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-167.671, Time=0.18 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-165.482, Time=0.82 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-167.458, Time=0.55 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.06 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 3.612 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=7114.605, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=6523.313, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=7108.019, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6383.563, Time=0.08 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6299.515, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6263.766, Time=0.14 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6235.976, Time=0.15 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.58 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.49 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6229.376, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6257.164, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.42 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.34 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 2.998 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=4.40 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1439.465, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.43 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.48 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2367.353, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.01 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.39 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.76 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=624.587, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.52 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.37 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=223.386, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.93 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.59 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.56 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=81.721, Time=0.16 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.27 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.73 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.48 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-275.812, Time=0.20 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.60 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.90 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.03 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-731.229, Time=0.66 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-6236.516, Time=3.81 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-7184.683, Time=7.72 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=8.30 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=2.71 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : BIC=-6719.268, Time=7.83 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.53 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-7560.140, Time=6.19 sec
#  ARIMA(5,0,1)(1,0,0)[12] intercept   : BIC=-6262.508, Time=2.25 sec
#  ARIMA(5,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=7.21 sec
#  ARIMA(5,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=2.29 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.35 sec
#  ARIMA(5,0,2)(2,0,0)[12] intercept   : BIC=-5107.443, Time=8.26 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-6687.197, Time=5.00 sec
#  ARIMA(5,0,1)(2,0,0)[12]             : BIC=-8445.911, Time=4.35 sec
#  ARIMA(5,0,1)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(5,0,1)(2,0,1)[12]             : BIC=inf, Time=13.29 sec
#  ARIMA(5,0,1)(1,0,1)[12]             : BIC=inf, Time=5.11 sec
#  ARIMA(4,0,1)(2,0,0)[12]             : BIC=-9660.989, Time=7.68 sec
#  ARIMA(4,0,1)(1,0,0)[12]             : BIC=-8560.564, Time=2.42 sec
#  ARIMA(4,0,1)(2,0,1)[12]             : BIC=inf, Time=7.85 sec
#  ARIMA(4,0,1)(1,0,1)[12]             : BIC=inf, Time=2.30 sec
#  ARIMA(3,0,1)(2,0,0)[12]             : BIC=-8946.174, Time=2.77 sec
#  ARIMA(4,0,0)(2,0,0)[12]             : BIC=inf, Time=1.29 sec
#  ARIMA(4,0,2)(2,0,0)[12]             : BIC=-9346.097, Time=6.18 sec
#  ARIMA(3,0,0)(2,0,0)[12]             : BIC=inf, Time=1.77 sec
#  ARIMA(3,0,2)(2,0,0)[12]             : BIC=-8326.065, Time=2.72 sec
#  ARIMA(5,0,0)(2,0,0)[12]             : BIC=inf, Time=5.33 sec
#  ARIMA(5,0,2)(2,0,0)[12]             : BIC=inf, Time=nan sec
#
# Best model:  ARIMA(4,0,1)(2,0,0)[12]
# Total fit time: 173.497 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2151.895, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=155.121, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1406.943, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=133.711, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=101.749, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=84.672, Time=0.06 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.06 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.32 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.29 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : BIC=inf, Time=0.39 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-169.641, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-155.273, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-185.868, Time=0.20 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-183.507, Time=0.68 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-185.540, Time=0.82 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 3.571 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=11957.445, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.10 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.15 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=9831.289, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7245.134, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=6613.876, Time=0.11 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=6494.240, Time=0.18 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6386.579, Time=0.16 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6360.752, Time=0.42 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.64 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.21 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.792 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=4.15 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1466.196, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.01 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.49 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2406.499, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.77 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.49 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.42 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=635.097, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.50 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.41 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=220.330, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.83 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.58 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.97 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=71.088, Time=0.14 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.69 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.64 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.55 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-288.888, Time=0.24 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.87 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.85 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.91 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.41 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-735.514, Time=0.57 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-9181.257, Time=4.49 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-7426.596, Time=5.05 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=1.41 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=5.75 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : BIC=-7216.559, Time=1.78 sec
#  ARIMA(5,0,1)(1,0,0)[12] intercept   : BIC=-6203.587, Time=2.29 sec
#  ARIMA(4,0,2)(1,0,0)[12] intercept   : BIC=-7799.150, Time=2.43 sec
#  ARIMA(3,0,2)(1,0,0)[12] intercept   : BIC=-6401.875, Time=2.04 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.71 sec
#  ARIMA(5,0,2)(1,0,0)[12] intercept   : BIC=inf, Time=4.09 sec
#  ARIMA(4,0,1)(1,0,0)[12]             : BIC=-8146.455, Time=1.79 sec
#
# Best model:  ARIMA(4,0,1)(1,0,0)[12] intercept
# Total fit time: 67.418 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2188.700, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=162.411, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1430.140, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=141.395, Time=0.04 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=106.781, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=89.866, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.38 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.36 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : BIC=inf, Time=0.51 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-169.443, Time=0.18 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-153.584, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-185.432, Time=0.20 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-182.797, Time=0.89 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-185.208, Time=0.54 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 3.977 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=12146.752, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=9982.321, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7366.445, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=6718.662, Time=0.10 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=6598.401, Time=0.20 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6488.635, Time=0.16 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6464.883, Time=0.28 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.57 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.35 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.286 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=2.21 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1489.140, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.05 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.42 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2444.565, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.09 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.93 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=644.500, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.53 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.00 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=223.361, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.57 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.65 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.97 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=68.182, Time=0.13 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.00 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.65 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.57 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-290.231, Time=0.20 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.66 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.03 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.04 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.37 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-748.853, Time=0.80 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-6810.899, Time=3.28 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-7871.532, Time=4.97 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=10.85 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=2.59 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : BIC=-7037.821, Time=6.58 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=7.67 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-7496.724, Time=6.01 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-7700.393, Time=5.70 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=7.80 sec
#  ARIMA(3,0,2)(2,0,0)[12] intercept   : BIC=inf, Time=11.72 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.54 sec
#  ARIMA(5,0,2)(2,0,0)[12] intercept   : BIC=-6236.799, Time=11.86 sec
#  ARIMA(4,0,1)(2,0,0)[12]             : BIC=-8750.596, Time=3.90 sec
#  ARIMA(4,0,1)(1,0,0)[12]             : BIC=-8865.442, Time=1.51 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=422.096, Time=0.14 sec
#  ARIMA(4,0,1)(1,0,1)[12]             : BIC=inf, Time=3.68 sec
#  ARIMA(4,0,1)(0,0,1)[12]             : BIC=inf, Time=1.04 sec
#  ARIMA(4,0,1)(2,0,1)[12]             : BIC=inf, Time=9.90 sec
#  ARIMA(3,0,1)(1,0,0)[12]             : BIC=-6609.977, Time=0.48 sec
#  ARIMA(4,0,0)(1,0,0)[12]             : BIC=inf, Time=1.13 sec
#  ARIMA(5,0,1)(1,0,0)[12]             : BIC=-6880.301, Time=7.51 sec
#  ARIMA(4,0,2)(1,0,0)[12]             : BIC=inf, Time=2.85 sec
#  ARIMA(3,0,0)(1,0,0)[12]             : BIC=inf, Time=0.87 sec
#  ARIMA(3,0,2)(1,0,0)[12]             : BIC=-7048.130, Time=1.05 sec
#  ARIMA(5,0,0)(1,0,0)[12]             : BIC=inf, Time=1.59 sec
#  ARIMA(5,0,2)(1,0,0)[12]             : BIC=inf, Time=15.95 sec
#
# Best model:  ARIMA(4,0,1)(1,0,0)[12]
# Total fit time: 162.628 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2223.690, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=165.780, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1452.639, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=144.695, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=110.268, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=92.357, Time=0.06 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.33 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.29 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : BIC=inf, Time=0.39 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-172.866, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-157.001, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-187.901, Time=0.20 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-185.473, Time=0.72 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-188.614, Time=0.73 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : BIC=-188.313, Time=0.49 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : BIC=-176.256, Time=0.60 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : BIC=-180.413, Time=0.53 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : BIC=-178.712, Time=0.92 sec
#
# Best model:  ARIMA(4,0,1)(0,0,0)[0] intercept
# Total fit time: 6.099 seconds
# 0.8465437500554445
#             flow(m^3/s)
# 2009-01-01   185.821102
# 2009-02-01   178.073142
# 2009-03-01   230.988014
# 2009-04-01   381.645968
# 2009-05-01   620.256166
# ...                 ...
# 2014-08-01   904.127721
# 2014-09-01   991.580247
# 2014-10-01   843.792703
# 2014-11-01   436.845695
# 2014-12-01   212.061426
#
# [72 rows x 1 columns]
# 0.6084004278486685
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.38 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=6773.615, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=6217.637, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=6767.055, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6084.398, Time=0.08 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6008.107, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=5974.998, Time=0.14 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=5949.048, Time=0.15 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.56 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.48 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=5942.487, Time=0.09 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=5968.437, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.43 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.34 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.024 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=2.19 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=10517.524, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=10510.962, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.05 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.14 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.50 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=9756.675, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.32 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.66 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=9414.689, Time=0.06 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=4.49 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.34 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.71 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=9263.133, Time=0.10 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.51 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=12.65 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=8967.074, Time=0.11 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.92 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.87 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=8864.718, Time=0.15 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.08 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.41 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.61 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=8858.154, Time=0.13 sec
#  ARIMA(5,0,0)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,1)[12]             : BIC=inf, Time=1.06 sec
#  ARIMA(5,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=8960.512, Time=0.08 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.69 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.61 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[12]
# Total fit time: 63.118 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=9827.293, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=9764.058, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=9753.278, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=9759.745, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=9759.532, Time=0.11 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.38 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=9759.836, Time=0.09 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.993 seconds
# Performing stepwise search to minimize bic
# C:\Users\ZJY\AppData\Local\Temp\ipykernel_39020\2992677552.py:69: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.52 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=6887.611, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=6314.784, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=6881.084, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6177.100, Time=0.08 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6097.139, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6061.071, Time=0.14 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6030.610, Time=0.18 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.62 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.47 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6024.043, Time=0.09 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6054.508, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.51 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.54 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.569 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=8265.544, Time=1.36 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=10702.542, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.38 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=10695.962, Time=0.02 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : BIC=inf, Time=1.46 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : BIC=8045.536, Time=2.67 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : BIC=inf, Time=0.42 sec
#  ARIMA(2,0,2)(2,0,0)[12] intercept   : BIC=inf, Time=4.37 sec
#  ARIMA(2,0,2)(2,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(1,0,2)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : BIC=inf, Time=4.81 sec
#  ARIMA(3,0,2)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : BIC=1611.059, Time=2.40 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : BIC=9744.695, Time=0.12 sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : BIC=5059.349, Time=1.75 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.39 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,1)(1,0,0)[12] intercept   : BIC=inf, Time=0.57 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.23 sec
#  ARIMA(0,0,2)(1,0,0)[12] intercept   : BIC=745.229, Time=1.40 sec
#  ARIMA(0,0,2)(0,0,0)[12] intercept   : BIC=9844.634, Time=0.22 sec
#  ARIMA(0,0,2)(2,0,0)[12] intercept   : BIC=inf, Time=3.44 sec
#  ARIMA(0,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=3.67 sec
#  ARIMA(0,0,2)(0,0,1)[12] intercept   : BIC=inf, Time=0.87 sec
#  ARIMA(0,0,2)(2,0,1)[12] intercept   : BIC=inf, Time=2.32 sec
#  ARIMA(0,0,3)(1,0,0)[12] intercept   : BIC=inf, Time=0.78 sec
#  ARIMA(1,0,3)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,2)(1,0,0)[12]             : BIC=inf, Time=nan sec
#
# Best model:  ARIMA(0,0,2)(1,0,0)[12] intercept
# Total fit time: 89.037 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=9984.727, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=9919.620, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=9908.569, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=9915.030, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=9914.798, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.26 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=9915.148, Time=0.08 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.779 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.36 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=7013.952, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=6427.109, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.10 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=7007.521, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6293.819, Time=0.07 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6211.347, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6178.955, Time=0.16 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6154.003, Time=0.17 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.52 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.56 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6147.464, Time=0.09 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6172.419, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.42 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.37 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.111 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=3.06 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=10884.988, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.03 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=10878.392, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.20 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.24 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=10101.845, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.35 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.25 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=9763.688, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.36 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=16.17 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=9597.891, Time=0.08 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.38 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.77 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=9285.355, Time=0.11 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.77 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.15 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.19 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.66 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.39 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.89 sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=9278.759, Time=0.08 sec
#  ARIMA(4,0,0)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12]             : BIC=inf, Time=0.72 sec
#  ARIMA(4,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,0)[12]             : BIC=9591.293, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=inf, Time=0.18 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.85 sec
#  ARIMA(3,0,1)(0,0,0)[12]             : BIC=inf, Time=0.68 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.98 sec
#
# Best model:  ARIMA(4,0,0)(0,0,0)[12]
# Total fit time: 50.749 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=10157.978, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=10093.294, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=10080.392, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=10087.027, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=10086.869, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.20 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=10086.986, Time=0.09 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.902 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.32 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=7114.605, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=6523.313, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=7108.019, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6383.563, Time=0.10 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6299.515, Time=0.13 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6263.766, Time=0.14 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6235.976, Time=0.19 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.88 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.85 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6229.376, Time=0.14 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6257.164, Time=0.13 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.68 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.52 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 4.371 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=1.45 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=11061.063, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.56 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.40 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=11054.451, Time=0.04 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.24 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.19 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.66 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=10270.511, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.36 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=9935.685, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=18.97 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.33 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.40 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=9777.847, Time=0.07 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.46 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=9452.399, Time=0.13 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.84 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.20 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.66 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.47 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.72 sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=9445.787, Time=0.07 sec
#  ARIMA(4,0,0)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12]             : BIC=inf, Time=0.74 sec
#  ARIMA(4,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,0)[12]             : BIC=9771.233, Time=0.06 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=inf, Time=0.10 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.59 sec
#  ARIMA(3,0,1)(0,0,0)[12]             : BIC=inf, Time=0.44 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.49 sec
#
# Best model:  ARIMA(4,0,0)(0,0,0)[12]
# Total fit time: 95.941 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.40 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=10318.394, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=10252.036, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=10238.603, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=10245.264, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=10245.111, Time=0.10 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.30 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=10245.207, Time=0.12 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 1.046 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=11957.445, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=9831.289, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7245.134, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=6613.876, Time=0.13 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=6494.240, Time=0.29 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6386.579, Time=0.19 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6360.752, Time=0.28 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.57 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.38 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.09 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.633 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=11253.485, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.38 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=11246.857, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.26 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.19 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.33 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=10445.151, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.28 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=10095.364, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.38 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=9927.141, Time=0.08 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.67 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=3.42 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=9597.851, Time=0.12 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.85 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.39 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.18 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.35 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.24 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.55 sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=9591.222, Time=0.08 sec
#  ARIMA(4,0,0)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12]             : BIC=inf, Time=0.82 sec
#  ARIMA(4,0,0)(1,0,1)[12]             : BIC=inf, Time=1.83 sec
#  ARIMA(3,0,0)(0,0,0)[12]             : BIC=9920.511, Time=0.06 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=inf, Time=0.11 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.53 sec
#  ARIMA(3,0,1)(0,0,0)[12]             : BIC=inf, Time=0.19 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.55 sec
#
# Best model:  ARIMA(4,0,0)(0,0,0)[12]
# Total fit time: 50.307 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.21 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=10510.134, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=10441.549, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=10425.422, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=10432.184, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=10432.046, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.28 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=10432.050, Time=0.13 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.839 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=12146.752, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=9982.321, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7366.445, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=6718.662, Time=0.12 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=6598.401, Time=0.21 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6488.635, Time=0.16 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6464.883, Time=0.28 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.61 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.36 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.08 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.521 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=11431.346, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=3.15 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.31 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=11424.702, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.77 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.22 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.43 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=10608.683, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.27 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.50 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=10251.870, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=6.70 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.42 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.79 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=10076.101, Time=0.19 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.46 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.90 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=9746.127, Time=0.13 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.98 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.16 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.32 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.29 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.73 sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=9739.483, Time=0.07 sec
#  ARIMA(4,0,0)(1,0,0)[12]             : BIC=inf, Time=3.13 sec
#  ARIMA(4,0,0)(0,0,1)[12]             : BIC=inf, Time=0.81 sec
#  ARIMA(4,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,0)[12]             : BIC=10069.456, Time=0.04 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=inf, Time=0.10 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.61 sec
#  ARIMA(3,0,1)(0,0,0)[12]             : BIC=inf, Time=0.37 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.37 sec
#
# Best model:  ARIMA(4,0,0)(0,0,0)[12]
# Total fit time: 73.180 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=10671.289, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=10601.575, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=10584.911, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=10591.537, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=10591.393, Time=0.06 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.26 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=10591.555, Time=0.05 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.692 seconds
# 0.7251566759987297
#             flow(m^3/s)
# 2009-01-01   184.633836
# 2009-02-01    68.282243
# 2009-03-01   194.643022
# 2009-04-01   512.902025
# 2009-05-01   801.765266
# ...                 ...
# 2014-08-01  1076.904886
# 2014-09-01   941.341790
# 2014-10-01   686.700012
# 2014-11-01   409.706257
# 2014-12-01   191.916260
#
# [72 rows x 1 columns]
# 0.6008093983128928

# %%
pred_years = [2015,2016,2017,2018,2019]
test_obs = df.loc["2015-01-01":"2019-12-31",:]
for hydro_station in hydro_stations:
    df = pd.read_csv(f'../data/{hydro_station.lower()}_natural_monthly_flow.csv', parse_dates=['date'], index_col='date')
    modes = [
        'multiplicative',
        # 'additive'
    ]
    for mode in modes:
        test_pred = pd.DataFrame()
        train_r2_list = []
        for year in pred_years:
            train = df.loc[:"{}-12-31".format(year-1),:]
            test = df.loc["{}-01-01".format(year):"{}-12-31".format(year),:]
            # decompose the data using seasonal_decompose
            decomposition = seasonal_decompose(train['flow(m^3/s)'], model=mode, period=12,extrapolate_trend=1)
            # decomposition = seasonal_decompose(train['flow(m^3/s)'], model='additive', period=12,extrapolate_trend=1)
            # extract the trend component
            trend = decomposition.trend
            seasonal = decomposition.seasonal
            residual = decomposition.resid
            # fit the ARIMA model to the trend component
            model = pm.auto_arima(trend, 
                                  seasonal=False, 
                                  information_criterion='bic',
                                  trace=True,
                                  error_action='ignore',  
                                  suppress_warnings=True, 
                                  stepwise=True)
            model.summary()
            train_trend_pred = model.predict_in_sample()
            test_trend_pred = model.predict(n_periods=len(test))
            # fit the ARIMA model to the seasonal component
            model = pm.auto_arima(seasonal, 
                                  m = 12,
                                  seasonal_test = 'ch',
                                  seasonal=True, 
                                  information_criterion='bic',
                                  trace=True,
                                  error_action='ignore',  
                                  suppress_warnings=True, 
                                  stepwise=True)
            model.summary()
            train_seasonal_pred = model.predict_in_sample()
            test_seasonal_pred = model.predict(n_periods=len(test))
            # fit the ARIMA model to the residual component
            model = pm.auto_arima(residual, 
                                  seasonal=False, 
                                  information_criterion='bic',
                                  trace=True,
                                  error_action='ignore',  
                                  suppress_warnings=True, 
                                  stepwise=True)
            model.summary()
            train_residual_pred = model.predict_in_sample()
            test_residual_pred = model.predict(n_periods=len(test))
            # combine the trend, seasonal, and residual components
            if mode == 'multiplicative':
                train_pred_year = train_trend_pred * train_seasonal_pred * train_residual_pred
                test_pred_year = test_trend_pred * test_seasonal_pred * test_residual_pred
            else:
                train_pred_year = train_trend_pred + train_seasonal_pred + train_residual_pred
                test_pred_year = test_trend_pred + test_seasonal_pred + test_residual_pred

            train_pred_year.index = train.index
            train_pred_year.name = "SimFlow(m^3/s)"
            train_result = pd.concat([train,train_pred_year],axis=1)
            train_result.to_csv(f'../result/ARIMAPredData/seasonal_decompose_{mode}_arima_train_sim_{hydro_station.lower()}_before_{year}.csv')
            train_r2 = r2_score(train['flow(m^3/s)'], train_pred_year)
            train_r2_list.append(train_r2)
            test_pred_year.index = test.index
            test_pred_year.name = "flow(m^3/s)"
            test_pred = pd.concat([test_pred,test_pred_year])

        print(sum(train_r2_list)/len(train_r2_list))
        print(r2_score(test_obs,test_pred)) # 0.6934 multiplicative;0.5988 additive
        test_pred.index.name = 'date'
        test_pred.to_csv(f'../result/ARIMAPredData/seasonal_decompose_{mode}_arima_pred_{hydro_station.lower()}_{pred_years[0]}_{pred_years[-1]}.csv')

        # visualize the results using plotly
        fig = go.Figure()
        fig.add_trace(go.Scatter(x=test_obs.index, y=test_obs['flow(m^3/s)'], mode='lines', name='Observed'))
        fig.add_trace(go.Scatter(x=test_pred.index, y=test_pred['flow(m^3/s)'], mode='lines', name='Predicted'))
        fig.show()

        # Best model:  ARIMA(5,0,1)(0,0,0)[0] intercept m=1
        # Total fit time: 5.661 seconds
        # 0.8163614700601103
        # 0.6934717968558676

        # Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept m=6
        # Total fit time: 4.456 seconds
        # 0.8403380825495306
        # 0.7699084203586042
# Out:
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2014-08-01    672.024750
# 2014-09-01    692.477439
# 2014-10-01    712.930127
# 2014-11-01    733.382815
# 2014-12-01    753.835503
# Name: trend, Length: 780, dtype: float64
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=12336.621, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.11 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=10127.252, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7476.811, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=6823.427, Time=0.11 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=6702.917, Time=0.17 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6590.523, Time=0.16 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6564.805, Time=0.32 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.54 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.36 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.09 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.276 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=1.67 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1511.257, Time=0.04 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.29 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.60 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2482.395, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.78 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.57 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.17 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=651.782, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.92 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=216.757, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.42 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.54 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.24 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=63.291, Time=0.13 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=4.37 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.80 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.15 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-301.793, Time=0.20 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.25 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.56 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.99 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.34 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-763.619, Time=0.69 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-5816.187, Time=2.19 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-7740.954, Time=5.94 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=-219.539, Time=2.15 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=3.18 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : BIC=-7473.039, Time=8.40 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.41 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-7648.808, Time=5.95 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-7932.511, Time=9.10 sec
#  ARIMA(4,0,2)(1,0,0)[12] intercept   : BIC=-7472.999, Time=3.63 sec
#  ARIMA(4,0,2)(2,0,1)[12] intercept   : BIC=-9135.085, Time=7.58 sec
#  ARIMA(4,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=5.13 sec
#  ARIMA(4,0,2)(2,0,2)[12] intercept   : BIC=inf, Time=5.04 sec
#  ARIMA(4,0,2)(1,0,2)[12] intercept   : BIC=inf, Time=7.59 sec
#  ARIMA(3,0,2)(2,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,2)(2,0,1)[12] intercept   : BIC=-9099.673, Time=5.56 sec
#  ARIMA(4,0,3)(2,0,1)[12] intercept   : BIC=-7584.557, Time=9.78 sec
#  ARIMA(3,0,1)(2,0,1)[12] intercept   : BIC=-9336.312, Time=5.43 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=2.63 sec
#  ARIMA(3,0,1)(2,0,2)[12] intercept   : BIC=inf, Time=8.74 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : BIC=-5247.943, Time=2.39 sec
#  ARIMA(3,0,1)(1,0,2)[12] intercept   : BIC=inf, Time=4.95 sec
#  ARIMA(2,0,1)(2,0,1)[12] intercept   : BIC=-7413.660, Time=2.97 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : BIC=-9618.377, Time=4.13 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=8.30 sec
#  ARIMA(3,0,0)(2,0,2)[12] intercept   : BIC=inf, Time=6.38 sec
#  ARIMA(3,0,0)(1,0,2)[12] intercept   : BIC=inf, Time=5.48 sec
#  ARIMA(2,0,0)(2,0,1)[12] intercept   : BIC=-9813.552, Time=4.36 sec
#  ARIMA(2,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.86 sec
#  ARIMA(2,0,0)(2,0,2)[12] intercept   : BIC=inf, Time=5.24 sec
#  ARIMA(2,0,0)(1,0,2)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(1,0,0)(2,0,1)[12] intercept   : BIC=-8637.265, Time=3.46 sec
#  ARIMA(1,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=3.79 sec
#  ARIMA(2,0,0)(2,0,1)[12]             : BIC=-8791.054, Time=1.31 sec
#
# Best model:  ARIMA(2,0,0)(2,0,1)[12] intercept
# Total fit time: 194.556 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.30 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2255.911, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=162.051, Time=0.06 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1471.952, Time=0.03 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=140.137, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=104.822, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=87.560, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.36 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.28 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : BIC=inf, Time=0.43 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-182.946, Time=0.15 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-165.992, Time=0.10 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-198.445, Time=0.20 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-195.884, Time=0.72 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-199.021, Time=0.47 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : BIC=-198.238, Time=0.48 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : BIC=-186.192, Time=0.62 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : BIC=-190.239, Time=0.57 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : BIC=-189.056, Time=0.75 sec
#
# Best model:  ARIMA(4,0,1)(0,0,0)[0] intercept
# Total fit time: 5.769 seconds
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2015-08-01    436.527912
# 2015-09-01    419.313172
# 2015-10-01    402.098432
# 2015-11-01    384.883692
# 2015-12-01    367.668952
# Name: trend, Length: 792, dtype: float64
# Performing stepwise search to minimize bic
# C:\Users\ZJY\AppData\Local\Temp\ipykernel_39020\620897473.py:71: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=12519.403, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.06 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=10284.412, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7586.987, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=6925.835, Time=0.11 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=6802.647, Time=0.20 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6687.415, Time=0.17 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6661.356, Time=0.32 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.58 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.44 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.455 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=6.34 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1533.287, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.33 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.50 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2520.200, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.02 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.40 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.56 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=671.238, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.53 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.17 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=260.696, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.45 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.61 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.75 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=106.125, Time=0.21 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.78 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.66 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.38 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-273.110, Time=0.19 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.54 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.90 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.77 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.29 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-748.544, Time=0.77 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-8127.079, Time=1.92 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-7202.940, Time=6.25 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=3.25 sec
#  ARIMA(4,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=2.09 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=6.46 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : BIC=-5820.959, Time=1.88 sec
#  ARIMA(5,0,1)(1,0,0)[12] intercept   : BIC=-7129.432, Time=2.31 sec
#  ARIMA(4,0,2)(1,0,0)[12] intercept   : BIC=-5673.304, Time=3.54 sec
#  ARIMA(3,0,2)(1,0,0)[12] intercept   : BIC=inf, Time=2.18 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.85 sec
#  ARIMA(5,0,2)(1,0,0)[12] intercept   : BIC=-6246.249, Time=2.52 sec
#  ARIMA(4,0,1)(1,0,0)[12]             : BIC=-8930.182, Time=0.96 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=454.928, Time=0.13 sec
#  ARIMA(4,0,1)(2,0,0)[12]             : BIC=-8701.561, Time=2.15 sec
#  ARIMA(4,0,1)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,1)(0,0,1)[12]             : BIC=inf, Time=1.06 sec
#  ARIMA(4,0,1)(2,0,1)[12]             : BIC=inf, Time=7.70 sec
#  ARIMA(3,0,1)(1,0,0)[12]             : BIC=-8966.688, Time=1.23 sec
#  ARIMA(3,0,1)(0,0,0)[12]             : BIC=471.740, Time=0.15 sec
#  ARIMA(3,0,1)(2,0,0)[12]             : BIC=-9376.735, Time=1.94 sec
#  ARIMA(3,0,1)(2,0,1)[12]             : BIC=inf, Time=2.06 sec
#  ARIMA(3,0,1)(1,0,1)[12]             : BIC=inf, Time=3.37 sec
#  ARIMA(2,0,1)(2,0,0)[12]             : BIC=-10060.507, Time=6.38 sec
#  ARIMA(2,0,1)(1,0,0)[12]             : BIC=-8894.483, Time=0.75 sec
#  ARIMA(2,0,1)(2,0,1)[12]             : BIC=inf, Time=8.03 sec
#  ARIMA(2,0,1)(1,0,1)[12]             : BIC=inf, Time=1.01 sec
#  ARIMA(1,0,1)(2,0,0)[12]             : BIC=-10660.991, Time=4.17 sec
#  ARIMA(1,0,1)(1,0,0)[12]             : BIC=-9656.062, Time=0.86 sec
#  ARIMA(1,0,1)(2,0,1)[12]             : BIC=inf, Time=0.73 sec
#  ARIMA(1,0,1)(1,0,1)[12]             : BIC=inf, Time=1.48 sec
#  ARIMA(0,0,1)(2,0,0)[12]             : BIC=-8395.735, Time=1.61 sec
#  ARIMA(1,0,0)(2,0,0)[12]             : BIC=inf, Time=1.76 sec
#  ARIMA(1,0,2)(2,0,0)[12]             : BIC=-7708.181, Time=1.88 sec
#  ARIMA(0,0,0)(2,0,0)[12]             : BIC=inf, Time=1.06 sec
#  ARIMA(0,0,2)(2,0,0)[12]             : BIC=inf, Time=1.18 sec
#  ARIMA(2,0,0)(2,0,0)[12]             : BIC=inf, Time=10.28 sec
#  ARIMA(2,0,2)(2,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(1,0,1)(2,0,0)[12] intercept   : BIC=-9500.464, Time=5.14 sec
#
# Best model:  ARIMA(1,0,1)(2,0,0)[12]
# Total fit time: 131.003 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.34 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2293.675, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=170.557, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1496.691, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=148.433, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=110.341, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=inf, Time=0.06 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.29 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : BIC=inf, Time=0.23 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.43 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-160.773, Time=0.10 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=-154.401, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-177.542, Time=0.18 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-191.032, Time=0.30 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-188.306, Time=0.85 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-191.958, Time=0.76 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : BIC=-190.911, Time=0.66 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : BIC=-180.052, Time=0.67 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : BIC=-183.144, Time=0.62 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : BIC=-181.226, Time=0.91 sec
#
# Best model:  ARIMA(4,0,1)(0,0,0)[0] intercept
# Total fit time: 6.649 seconds
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2016-08-01    441.401996
# 2016-09-01    446.129281
# 2016-10-01    450.856566
# 2016-11-01    455.583851
# 2016-12-01    460.311136
# Name: trend, Length: 804, dtype: float64
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=7675.256, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=7045.665, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.14 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=7668.659, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6892.711, Time=0.11 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6797.746, Time=0.11 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6755.470, Time=0.14 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6720.718, Time=0.17 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.58 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.48 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6714.047, Time=0.09 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6748.809, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.59 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.35 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.409 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=2.60 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1550.501, Time=0.05 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.99 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.51 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2556.636, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.17 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.39 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.12 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=675.428, Time=0.06 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.77 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.09 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=258.598, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.54 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.73 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.99 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=105.278, Time=0.25 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.27 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.66 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.47 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-287.785, Time=0.20 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.48 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.95 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.92 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.47 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-781.945, Time=0.79 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-7839.915, Time=1.80 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-7858.645, Time=9.82 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=5.99 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=3.40 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : BIC=-7534.416, Time=7.08 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.52 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-8173.800, Time=6.02 sec
#  ARIMA(5,0,1)(1,0,0)[12] intercept   : BIC=-7391.822, Time=2.35 sec
#  ARIMA(5,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=10.14 sec
#  ARIMA(5,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=3.53 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.23 sec
#  ARIMA(5,0,2)(2,0,0)[12] intercept   : BIC=-6969.186, Time=10.83 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-8720.659, Time=8.28 sec
#  ARIMA(4,0,2)(1,0,0)[12] intercept   : BIC=-6687.037, Time=2.60 sec
#  ARIMA(4,0,2)(2,0,1)[12] intercept   : BIC=inf, Time=10.49 sec
#  ARIMA(4,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=2.35 sec
#  ARIMA(3,0,2)(2,0,0)[12] intercept   : BIC=-7737.547, Time=11.73 sec
#  ARIMA(4,0,3)(2,0,0)[12] intercept   : BIC=-7520.099, Time=9.75 sec
#  ARIMA(3,0,3)(2,0,0)[12] intercept   : BIC=-6249.467, Time=8.30 sec
#  ARIMA(5,0,3)(2,0,0)[12] intercept   : BIC=-8168.032, Time=10.38 sec
#  ARIMA(4,0,2)(2,0,0)[12]             : BIC=-10331.021, Time=11.74 sec
#  ARIMA(4,0,2)(1,0,0)[12]             : BIC=inf, Time=2.50 sec
#  ARIMA(4,0,2)(2,0,1)[12]             : BIC=inf, Time=21.44 sec
#  ARIMA(4,0,2)(1,0,1)[12]             : BIC=inf, Time=2.37 sec
#  ARIMA(3,0,2)(2,0,0)[12]             : BIC=-9360.645, Time=2.36 sec
#  ARIMA(4,0,1)(2,0,0)[12]             : BIC=-9871.639, Time=3.94 sec
#  ARIMA(5,0,2)(2,0,0)[12]             : BIC=-9782.180, Time=6.95 sec
#  ARIMA(4,0,3)(2,0,0)[12]             : BIC=-9502.218, Time=3.16 sec
#  ARIMA(3,0,1)(2,0,0)[12]             : BIC=-9632.607, Time=2.49 sec
#  ARIMA(3,0,3)(2,0,0)[12]             : BIC=-7745.852, Time=2.84 sec
#  ARIMA(5,0,1)(2,0,0)[12]             : BIC=-8576.267, Time=6.03 sec
#  ARIMA(5,0,3)(2,0,0)[12]             : BIC=-7867.855, Time=6.04 sec
#
# Best model:  ARIMA(4,0,2)(2,0,0)[12]
# Total fit time: 236.064 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.30 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2325.905, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=161.601, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1515.114, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=139.576, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=101.721, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=inf, Time=0.06 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.30 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : BIC=inf, Time=0.22 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.36 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-173.825, Time=0.20 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=-167.079, Time=0.07 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-191.239, Time=0.13 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-206.108, Time=0.25 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-203.682, Time=0.99 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-207.157, Time=0.58 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : BIC=-205.856, Time=0.64 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : BIC=-194.814, Time=0.61 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : BIC=-197.998, Time=0.43 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : BIC=-196.621, Time=0.70 sec
#
# Best model:  ARIMA(4,0,1)(0,0,0)[0] intercept
# Total fit time: 6.032 seconds
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2017-08-01    701.235721
# 2017-09-01    745.205120
# 2017-10-01    789.174520
# 2017-11-01    833.143920
# 2017-12-01    877.113319
# Name: trend, Length: 816, dtype: float64
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.31 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=7803.175, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=7157.348, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=7796.516, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=7015.394, Time=0.09 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6925.441, Time=0.11 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6890.944, Time=0.15 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6864.403, Time=0.16 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.61 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.41 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6857.721, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6884.259, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.46 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.38 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.102 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=3.76 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1567.721, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.20 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.71 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2593.082, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.86 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.04 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=680.971, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.54 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.24 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=256.166, Time=0.09 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.02 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.79 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.59 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=114.244, Time=0.13 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.29 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.07 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.39 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-301.684, Time=0.20 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.62 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.90 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=4.90 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.52 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-819.260, Time=0.70 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-7513.055, Time=3.85 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-6460.431, Time=5.79 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=2.02 sec
#  ARIMA(4,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=1.48 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=7.35 sec
#  ARIMA(3,0,1)(1,0,0)[12] intercept   : BIC=-6541.704, Time=6.63 sec
#  ARIMA(5,0,1)(1,0,0)[12] intercept   : BIC=-7552.155, Time=4.71 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=-768.783, Time=1.45 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-8803.126, Time=6.79 sec
#  ARIMA(5,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=10.28 sec
#  ARIMA(5,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=4.14 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=6.55 sec
#  ARIMA(5,0,2)(2,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=5.54 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-8831.712, Time=16.77 sec
#  ARIMA(4,0,2)(1,0,0)[12] intercept   : BIC=-5530.163, Time=4.86 sec
#  ARIMA(4,0,2)(2,0,1)[12] intercept   : BIC=inf, Time=11.25 sec
#  ARIMA(4,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=4.60 sec
#  ARIMA(3,0,2)(2,0,0)[12] intercept   : BIC=-6421.611, Time=6.40 sec
#  ARIMA(4,0,3)(2,0,0)[12] intercept   : BIC=-8600.692, Time=11.21 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : BIC=-7825.859, Time=16.19 sec
#  ARIMA(3,0,3)(2,0,0)[12] intercept   : BIC=-6258.621, Time=6.94 sec
#  ARIMA(5,0,3)(2,0,0)[12] intercept   : BIC=-7875.826, Time=8.61 sec
#  ARIMA(4,0,2)(2,0,0)[12]             : BIC=-9317.538, Time=29.98 sec
#  ARIMA(4,0,2)(1,0,0)[12]             : BIC=inf, Time=4.66 sec
#  ARIMA(4,0,2)(2,0,1)[12]             : BIC=inf, Time=7.59 sec
#  ARIMA(4,0,2)(1,0,1)[12]             : BIC=inf, Time=3.73 sec
#  ARIMA(3,0,2)(2,0,0)[12]             : BIC=-9914.467, Time=6.64 sec
#  ARIMA(3,0,2)(1,0,0)[12]             : BIC=-8685.560, Time=1.70 sec
#  ARIMA(3,0,2)(2,0,1)[12]             : BIC=inf, Time=3.46 sec
#  ARIMA(3,0,2)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(2,0,2)(2,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(3,0,1)(2,0,0)[12]             : BIC=-9881.521, Time=2.52 sec
#  ARIMA(3,0,3)(2,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(2,0,1)(2,0,0)[12]             : BIC=-10514.696, Time=3.97 sec
#  ARIMA(2,0,1)(1,0,0)[12]             : BIC=-10676.517, Time=1.17 sec
#  ARIMA(2,0,1)(0,0,0)[12]             : BIC=471.515, Time=0.13 sec
#  ARIMA(2,0,1)(1,0,1)[12]             : BIC=inf, Time=1.39 sec
#  ARIMA(2,0,1)(0,0,1)[12]             : BIC=inf, Time=0.56 sec
#  ARIMA(2,0,1)(2,0,1)[12]             : BIC=inf, Time=1.95 sec
#  ARIMA(1,0,1)(1,0,0)[12]             : BIC=-9789.914, Time=0.79 sec
#  ARIMA(2,0,0)(1,0,0)[12]             : BIC=inf, Time=0.98 sec
#  ARIMA(3,0,1)(1,0,0)[12]             : BIC=-8902.850, Time=1.58 sec
#  ARIMA(2,0,2)(1,0,0)[12]             : BIC=-8677.522, Time=4.09 sec
#  ARIMA(1,0,0)(1,0,0)[12]             : BIC=inf, Time=0.46 sec
#  ARIMA(1,0,2)(1,0,0)[12]             : BIC=inf, Time=1.14 sec
#  ARIMA(3,0,0)(1,0,0)[12]             : BIC=inf, Time=1.01 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : BIC=-6468.589, Time=1.88 sec
#
# Best model:  ARIMA(2,0,1)(1,0,0)[12]
# Total fit time: 279.374 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.47 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2358.405, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=167.236, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1538.073, Time=0.04 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=144.678, Time=0.03 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=106.063, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=87.982, Time=0.13 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.10 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.48 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.30 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : BIC=inf, Time=0.46 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-187.605, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-171.594, Time=0.17 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-204.374, Time=0.34 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-202.170, Time=1.08 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-204.849, Time=0.72 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : BIC=-203.571, Time=0.60 sec
#  ARIMA(4,0,2)(0,0,0)[0] intercept   : BIC=-191.632, Time=0.77 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : BIC=-195.955, Time=0.73 sec
#  ARIMA(5,0,2)(0,0,0)[0] intercept   : BIC=-195.145, Time=1.02 sec
#
# Best model:  ARIMA(4,0,1)(0,0,0)[0] intercept
# Total fit time: 7.701 seconds
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2018-08-01    899.528283
# 2018-09-01    894.233167
# 2018-10-01    888.938050
# 2018-11-01    883.642934
# 2018-12-01    878.347817
# Name: trend, Length: 828, dtype: float64
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.36 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=13088.812, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.05 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.08 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.10 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=10764.319, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7928.625, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=7231.097, Time=0.12 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=7100.613, Time=0.21 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6985.157, Time=0.22 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6959.365, Time=0.33 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.61 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.759 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=3.08 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=1594.797, Time=0.06 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.02 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.68 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=2632.316, Time=0.03 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.32 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.69 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=702.868, Time=0.07 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.55 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=3.29 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=296.631, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.46 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.69 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.61 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=144.487, Time=0.12 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.25 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.84 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.01 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=-266.868, Time=0.29 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.98 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.03 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=3.97 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.48 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=-803.771, Time=0.72 sec
#  ARIMA(4,0,1)(1,0,0)[12] intercept   : BIC=-8269.431, Time=3.46 sec
#  ARIMA(4,0,1)(2,0,0)[12] intercept   : BIC=-9085.768, Time=10.17 sec
#  ARIMA(4,0,1)(2,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=3.83 sec
#  ARIMA(3,0,1)(2,0,0)[12] intercept   : BIC=-7777.801, Time=10.33 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=8.60 sec
#  ARIMA(5,0,1)(2,0,0)[12] intercept   : BIC=-8609.713, Time=10.38 sec
#  ARIMA(4,0,2)(2,0,0)[12] intercept   : BIC=-6982.253, Time=6.98 sec
#  ARIMA(3,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=7.85 sec
#  ARIMA(3,0,2)(2,0,0)[12] intercept   : BIC=-8257.797, Time=11.14 sec
#  ARIMA(5,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=6.44 sec
#  ARIMA(5,0,2)(2,0,0)[12] intercept   : BIC=-8380.949, Time=11.39 sec
#  ARIMA(4,0,1)(2,0,0)[12]             : BIC=-9610.124, Time=1.87 sec
#  ARIMA(4,0,1)(1,0,0)[12]             : BIC=-9670.161, Time=1.31 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=488.784, Time=0.13 sec
#  ARIMA(4,0,1)(1,0,1)[12]             : BIC=inf, Time=4.00 sec
#  ARIMA(4,0,1)(0,0,1)[12]             : BIC=inf, Time=1.01 sec
#  ARIMA(4,0,1)(2,0,1)[12]             : BIC=-11334.160, Time=5.75 sec
#  ARIMA(4,0,1)(2,0,2)[12]             : BIC=inf, Time=7.22 sec
#  ARIMA(4,0,1)(1,0,2)[12]             : BIC=inf, Time=3.84 sec
#  ARIMA(3,0,1)(2,0,1)[12]             : BIC=-11328.365, Time=13.53 sec
#  ARIMA(4,0,0)(2,0,1)[12]             : BIC=-11338.030, Time=3.53 sec
#  ARIMA(4,0,0)(1,0,1)[12]             : BIC=inf, Time=2.76 sec
#  ARIMA(4,0,0)(2,0,0)[12]             : BIC=inf, Time=2.85 sec
#  ARIMA(4,0,0)(2,0,2)[12]             : BIC=inf, Time=5.68 sec
#  ARIMA(4,0,0)(1,0,0)[12]             : BIC=inf, Time=1.59 sec
#  ARIMA(4,0,0)(1,0,2)[12]             : BIC=inf, Time=3.17 sec
#  ARIMA(3,0,0)(2,0,1)[12]             : BIC=-11344.450, Time=10.44 sec
#  ARIMA(3,0,0)(1,0,1)[12]             : BIC=inf, Time=0.74 sec
#  ARIMA(3,0,0)(2,0,0)[12]             : BIC=inf, Time=1.51 sec
#  ARIMA(3,0,0)(2,0,2)[12]             : BIC=inf, Time=5.71 sec
#  ARIMA(3,0,0)(1,0,0)[12]             : BIC=inf, Time=0.82 sec
#  ARIMA(3,0,0)(1,0,2)[12]             : BIC=inf, Time=3.02 sec
#  ARIMA(2,0,0)(2,0,1)[12]             : BIC=-11341.922, Time=6.06 sec
#  ARIMA(2,0,1)(2,0,1)[12]             : BIC=-11341.190, Time=4.69 sec
#  ARIMA(3,0,0)(2,0,1)[12] intercept   : BIC=inf, Time=nan sec
#
# Best model:  ARIMA(3,0,0)(2,0,1)[12]
# Total fit time: 228.839 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.37 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=2397.217, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=174.046, Time=0.14 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=1565.854, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : BIC=150.228, Time=0.06 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : BIC=115.240, Time=0.05 sec
#  ARIMA(4,0,0)(0,0,0)[0]             : BIC=95.959, Time=0.07 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.08 sec
#  ARIMA(4,0,1)(0,0,0)[0]             : BIC=inf, Time=0.47 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : BIC=inf, Time=0.38 sec
#  ARIMA(5,0,1)(0,0,0)[0]             : BIC=inf, Time=0.47 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=-187.744, Time=0.16 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=-170.754, Time=0.18 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=-205.920, Time=0.35 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=-203.660, Time=1.19 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=-205.691, Time=0.70 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 4.784 seconds
# 0.8442303434178132
# 0.7699014706302801
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2014-08-01    672.024750
# 2014-09-01    692.477439
# 2014-10-01    712.930127
# 2014-11-01    733.382815
# 2014-12-01    753.835503
# Name: trend, Length: 780, dtype: float64
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=12336.621, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.12 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=10127.252, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7476.811, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=6823.427, Time=0.17 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=6702.917, Time=0.21 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6590.523, Time=0.16 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6564.805, Time=0.36 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.71 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.44 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.13 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.752 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=1.29 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=11606.963, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=11600.303, Time=0.07 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.22 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.20 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.28 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=10770.546, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.36 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.05 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=10401.652, Time=0.08 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=29.95 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.46 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=10229.180, Time=0.08 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.69 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.83 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=9897.164, Time=0.14 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=29.91 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.52 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=7.46 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=9791.768, Time=0.37 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.27 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.61 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.32 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=9785.107, Time=0.09 sec
#  ARIMA(5,0,0)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,1)[12]             : BIC=inf, Time=1.13 sec
#  ARIMA(5,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=9890.505, Time=0.07 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.53 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.52 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[12]
# Total fit time: 129.632 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.25 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=10830.618, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=10760.316, Time=0.04 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=10743.382, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=10750.023, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=10749.878, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.19 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=10750.036, Time=0.04 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.730 seconds
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2015-08-01    436.527912
# 2015-09-01    419.313172
# 2015-10-01    402.098432
# 2015-11-01    384.883692
# 2015-12-01    367.668952
# Name: trend, Length: 792, dtype: float64
# Performing stepwise search to minimize bic
# C:\Users\ZJY\AppData\Local\Temp\ipykernel_39020\620897473.py:71: FutureWarning:
#
# The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.24 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=12519.403, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.13 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=10284.412, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7586.987, Time=0.07 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=6925.835, Time=0.14 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=6802.647, Time=0.23 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6687.415, Time=0.21 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6661.356, Time=0.34 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.61 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.36 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.10 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.598 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=0.68 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=11779.749, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.29 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=11773.075, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.26 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.22 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.44 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=10936.131, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.34 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.38 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=10578.374, Time=0.07 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=10402.405, Time=0.09 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.79 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=13.50 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=10055.267, Time=0.15 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.93 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=20.49 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=9942.502, Time=0.18 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=8.68 sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.52 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.91 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.81 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=9935.826, Time=0.14 sec
#  ARIMA(5,0,0)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,1)[12]             : BIC=inf, Time=1.15 sec
#  ARIMA(5,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=10048.592, Time=0.07 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.56 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.53 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[12]
# Total fit time: 104.650 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=10991.084, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=10919.547, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=10902.047, Time=0.03 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=10908.702, Time=0.05 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=10908.551, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=10908.722, Time=0.05 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.747 seconds
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2016-08-01    441.401996
# 2016-09-01    446.129281
# 2016-10-01    450.856566
# 2016-11-01    455.583851
# 2016-12-01    460.311136
# Name: trend, Length: 804, dtype: float64
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=7675.256, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=7045.665, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=7668.659, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=6892.711, Time=0.09 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6797.746, Time=0.11 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6755.470, Time=0.15 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6720.718, Time=0.17 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.63 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.49 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6714.047, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6748.809, Time=0.09 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.55 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.34 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.401 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=11945.638, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.33 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=11938.948, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.77 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.19 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.61 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=11089.875, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.25 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.21 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=10727.471, Time=0.06 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=2.61 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.36 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=3.23 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=10552.504, Time=0.09 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=13.80 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.48 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.03 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=10195.564, Time=0.12 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.93 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=inf, Time=0.18 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.50 sec
#  ARIMA(3,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.27 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.76 sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=10188.874, Time=0.09 sec
#  ARIMA(4,0,0)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12]             : BIC=inf, Time=0.84 sec
#  ARIMA(4,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,0)[12]             : BIC=10545.813, Time=0.05 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=inf, Time=0.10 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.67 sec
#  ARIMA(3,0,1)(0,0,0)[12]             : BIC=inf, Time=0.42 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.47 sec
#
# Best model:  ARIMA(4,0,0)(0,0,0)[12]
# Total fit time: 58.216 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=11154.830, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=11079.031, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=11061.330, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=11068.154, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=11068.006, Time=0.08 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.22 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=11068.016, Time=0.09 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.779 seconds
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2017-08-01    701.235721
# 2017-09-01    745.205120
# 2017-10-01    789.174520
# 2017-11-01    833.143920
# 2017-12-01    877.113319
# Name: trend, Length: 816, dtype: float64
# Performing stepwise search to minimize bic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=inf, Time=0.35 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=7803.175, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=7157.348, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.13 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=7796.516, Time=0.03 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=7015.394, Time=0.10 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=6925.441, Time=0.13 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=6890.944, Time=0.16 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=6864.403, Time=0.18 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.64 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.43 sec
#  ARIMA(5,1,0)(0,0,0)[0]             : BIC=6857.721, Time=0.10 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=6884.259, Time=0.08 sec
#  ARIMA(5,1,1)(0,0,0)[0]             : BIC=inf, Time=0.48 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=inf, Time=0.36 sec
#
# Best model:  ARIMA(5,1,0)(0,0,0)[0]
# Total fit time: 3.276 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=2.15 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=12114.588, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.41 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=12107.884, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.73 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.18 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.42 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=11249.199, Time=0.04 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.33 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.41 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=10881.016, Time=0.04 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.35 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.07 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=10721.492, Time=0.07 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=15.15 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.49 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=2.76 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=10347.482, Time=0.12 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.08 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=-50.943, Time=3.22 sec
#  ARIMA(4,0,0)(2,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(1,0,2)[12] intercept   : BIC=inf, Time=2.74 sec
#  ARIMA(4,0,0)(0,0,2)[12] intercept   : BIC=inf, Time=3.14 sec
#  ARIMA(4,0,0)(2,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(2,0,2)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.57 sec
#  ARIMA(4,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=1.23 sec
#  ARIMA(3,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=0.85 sec
#  ARIMA(5,0,1)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#
# Best model:  ARIMA(4,0,0)(1,0,1)[12] intercept
# Total fit time: 100.828 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.23 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=11327.132, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=11249.479, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=11231.093, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=11237.931, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=11237.775, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.18 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=11237.783, Time=0.09 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.699 seconds
# date
# 1950-01-01    705.294220
# 1950-02-01    700.628644
# 1950-03-01    695.963068
# 1950-04-01    691.297491
# 1950-05-01    686.631915
#                  ...
# 2018-08-01    899.528283
# 2018-09-01    894.233167
# 2018-10-01    888.938050
# 2018-11-01    883.642934
# 2018-12-01    878.347817
# Name: trend, Length: 828, dtype: float64
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.22 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=13088.812, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=inf, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=inf, Time=0.07 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=inf, Time=0.09 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : BIC=10764.319, Time=0.03 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : BIC=7928.625, Time=0.06 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : BIC=7231.097, Time=0.11 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : BIC=7100.613, Time=0.21 sec
#  ARIMA(4,0,0)(0,0,0)[0] intercept   : BIC=6985.157, Time=0.17 sec
#  ARIMA(5,0,0)(0,0,0)[0] intercept   : BIC=6959.365, Time=0.36 sec
#  ARIMA(5,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.63 sec
#  ARIMA(4,0,1)(0,0,0)[0] intercept   : BIC=inf, Time=0.39 sec
#  ARIMA(5,0,0)(0,0,0)[0]             : BIC=inf, Time=0.09 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[0] intercept
# Total fit time: 2.461 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : BIC=12308.899, Time=0.03 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=8.74 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : BIC=inf, Time=0.32 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : BIC=12302.180, Time=0.02 sec
#  ARIMA(0,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=0.60 sec
#  ARIMA(0,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.23 sec
#  ARIMA(0,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.85 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : BIC=11440.284, Time=0.05 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.27 sec
#  ARIMA(1,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=1.67 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : BIC=11095.101, Time=0.05 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=1.40 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.34 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.37 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : BIC=10919.542, Time=0.07 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.46 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=0.46 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : BIC=10551.113, Time=0.14 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=0.97 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : BIC=10419.171, Time=0.17 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : BIC=inf, Time=1.66 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : BIC=inf, Time=16.79 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.67 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : BIC=inf, Time=0.70 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : BIC=10412.451, Time=0.15 sec
#  ARIMA(5,0,0)(1,0,0)[12]             : BIC=inf, Time=nan sec
#  ARIMA(5,0,0)(0,0,1)[12]             : BIC=inf, Time=1.11 sec
#  ARIMA(5,0,0)(1,0,1)[12]             : BIC=inf, Time=nan sec
#  ARIMA(4,0,0)(0,0,0)[12]             : BIC=10544.393, Time=0.07 sec
#  ARIMA(5,0,1)(0,0,0)[12]             : BIC=inf, Time=0.65 sec
#  ARIMA(4,0,1)(0,0,0)[12]             : BIC=inf, Time=0.66 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[12]
# Total fit time: 106.551 seconds
# Performing stepwise search to minimize bic
#  ARIMA(2,0,2)(0,0,0)[0]             : BIC=inf, Time=0.26 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : BIC=11500.787, Time=0.02 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : BIC=11424.636, Time=0.03 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : BIC=11410.011, Time=0.05 sec
#  ARIMA(1,0,1)(0,0,0)[0]             : BIC=11416.682, Time=0.04 sec
#  ARIMA(0,0,2)(0,0,0)[0]             : BIC=11416.444, Time=0.07 sec
#  ARIMA(1,0,2)(0,0,0)[0]             : BIC=inf, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : BIC=11416.729, Time=0.09 sec
#
# Best model:  ARIMA(0,0,1)(0,0,0)[0]
# Total fit time: 0.777 seconds
# 0.7296749055517563
# 0.6254543392681486
